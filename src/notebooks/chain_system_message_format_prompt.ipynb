# %%
import getpass
import os
from langchain_openai import ChatOpenAI
from langchain_core.prompts import (
    SystemMessagePromptTemplate, HumanMessagePromptTemplate, ChatPromptTemplate
)
os.environ["OPENAI_API_KEY"] = getpass.getpass(prompt="Enter OpenApi key:")
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model="gpt-4o-mini",temperature=0.9)


system_template = "You are a world Python code instructor. Provide answers with full code of unit tests."
system_message_prompt_template = SystemMessagePromptTemplate.from_template(
    system_template)

human_template = "{sample_code_request}"
human_message_prompt_template = HumanMessagePromptTemplate.from_template(human_template)
chat_prompt_template = ChatPromptTemplate.from_messages(
    [system_message_prompt_template, human_message_prompt_template])
# format the prompt by passing the sample_code_request parameter
final_prompt = chat_prompt_template.format_prompt(sample_code_request="Write me code to make a http request to a web page").to_messages()

# generate the output by calling ChatGPT model and passing the prompt
completion = llm.invoke(final_prompt)
print(completion.content)
# Out:
# To make an HTTP request to a web page in Python, you can use the `requests` library, which is simple and easy to use. Below is an example of how to make a GET request to a web page and print the response.
#
# ### Step 1: Install the Requests Library
#
# If you haven't already installed the `requests` library, you can do so by running:
#
# ```bash
# pip install requests
# ```
#
# ### Step 2: Making an HTTP Request
#
# Here is a simple Python script that makes an HTTP GET request to a specified URL and prints the response content:
#
# ```python
# import requests
#
# def fetch_web_page(url):
#     try:
#         response = requests.get(url)
#         response.raise_for_status()  # Raise an error for bad responses
#         return response.text  # Return the content of the response
#     except requests.RequestException as e:
#         return f"An error occurred: {e}"
#
# if __name__ == "__main__":
#     url = "https://www.example.com"  # Replace with your desired URL
#     content = fetch_web_page(url)
#     print(content)
# ```
#
# ### Explanation
#
# - The `fetch_web_page` function takes a URL as an argument.
# - It makes a GET request to that URL using `requests.get()`.
# - The `raise_for_status()` method throws an exception for HTTP error responses (like 404, 500, etc.).
# - If successful, it returns the content of the web page.
# - The script prints the web page content to the console.
#
# ### Unit Testing the Function
#
# To ensure that your function behaves as expected, you can write unit tests. Here's a basic example using the `unittest` framework. In a real-world scenario, you might want to mock HTTP requests using the `unittest.mock` module.
#
# ```python
# import unittest
# from unittest.mock import patch
# from my_module import fetch_web_page  # Assuming the function is defined in my_module.py
#
# class TestFetchWebPage(unittest.TestCase):
#
#     @patch('requests.get')
#     def test_fetch_web_page_success(self, mock_get):
#         # Arrange
#         mock_get.return_value.status_code = 200
#         mock_get.return_value.text = 'Test content'
#
#         # Act
#         result = fetch_web_page('http://test.com')
#
#         # Assert
#         self.assertEqual(result, 'Test content')
#         mock_get.assert_called_once_with('http://test.com')
#
#     @patch('requests.get')
#     def test_fetch_web_page_not_found(self, mock_get):
#         # Arrange
#         mock_get.side_effect = requests.HTTPError('404 Client Error: Not Found for url: http://test.com')
#
#         # Act
#         result = fetch_web_page('http://test.com')
#
#         # Assert
#         self.assertTrue("An error occurred" in result)
#
# if __name__ == '__main__':
#     unittest.main()
# ```
#
# ### Explanation of the Tests
#
# 1. **Test for Successful Response**:
#    - It mocks the `requests.get` method to return a response with a status code of 200 and some test content.
#    - Asserts that the returned content matches the expected content and that the `get` method was called with the correct URL.
#
# 2. **Test for Not Found Error**:
#    - It simulates an HTTP error (404) by setting `side_effect` on the mock.
#    - Checks that the returned result contains the expected error message.
#
# ### Running the Tests
#
# You can run the tests by executing the script. If everything is set up correctly, it should output the results of the tests, indicating whether they passed or failed.
#
# Make sure to replace `my_module` with the actual name of your Python file containing the `fetch_web_page` function if you're following this testing structure.
